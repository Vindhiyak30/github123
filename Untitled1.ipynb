# %% [markdown]
# <a href="https://colab.research.google.com/github/Vindhiyak30/github123/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=5
b=10
print(a-b)
# Out:
# -5

# %%
p=200
q=300
print(p+q)
# Out:
# 500

# %%
a=20
b=2
print(a*b)
# Out:
# 40

# %%
a=30
b=4
print(a*b)
# Out:
# 120

# %%
p=20
q=25
print(p/q)
# Out:
# 0.8

# %%
p=10
q=7
print(p//q)
# Out:
# 1

# %%
p=45
q=5
print(p%q)
# Out:
# 0

# %%
p=43
q=5
print(p%q)
# Out:
# 3

# %%
p=24
q=7
print(p//q)
# Out:
# 3
